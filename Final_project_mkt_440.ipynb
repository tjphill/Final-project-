# %% [markdown]
# <a href="https://colab.research.google.com/github/tjphill/Final-project-/blob/main/Final_project_mkt_440.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
url = "https://raw.githubusercontent.com/tjphill/Final-project-/main/marketing_data_spring2022.csv"
FP = pd.read_csv(url)

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
FP
# Out:
#          ID  Year_Birth         Education                 Marital_Status  \
# 0         0        1985  Bachelors_Degree                        Married
# 1         1        1961  Bachelors_Degree                         Single
# 2         9        1975            Master                         Single
# 3        13        1947               PhD                          Widow
# 4        17        1971               PhD                        Married
# ...     ...         ...               ...                            ...
# 2235  11178        1972            Master                         Single
# 2236  11181        1949               PhD                        Married
# 2237  11187        1978        HighSchool                         Single
# 2238  11188        1957  Bachelors_Degree  Living_with_Significant_Other
# 2239  11191        1986  Bachelors_Degree                       Divorced
#
#             Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  \
# ...

# %%
FP = FP.replace(['Bachelors_Degree'],'BachelorsDegree')

# %%
FP
# Out:
#          ID  Year_Birth        Education                 Marital_Status  \
# 0         0        1985  BachelorsDegree                        Married
# 1         1        1961  BachelorsDegree                         Single
# 2         9        1975           Master                         Single
# 3        13        1947              PhD                          Widow
# 4        17        1971              PhD                        Married
# ...     ...         ...              ...                            ...
# 2235  11178        1972           Master                         Single
# 2236  11181        1949              PhD                        Married
# 2237  11187        1978       HighSchool                         Single
# 2238  11188        1957  BachelorsDegree  Living_with_Significant_Other
# 2239  11191        1986  BachelorsDegree                       Divorced
#
#             Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  \
# ...

# %%
FP.corr()
# Out:
#                            ID  Year_Birth   Kidhome  Teenhome   Recency  \
# ID                   1.000000    0.000028  0.002406 -0.002580 -0.046524
# Year_Birth           0.000028    1.000000  0.230176 -0.352111 -0.019871
# Kidhome              0.002406    0.230176  1.000000 -0.036133  0.008827
# Teenhome            -0.002580   -0.352111 -0.036133  1.000000  0.016198
# Recency             -0.046524   -0.019871  0.008827  0.016198  1.000000
# MntWines            -0.022878   -0.157773 -0.496297  0.004846  0.016064
# MntFruits            0.004600   -0.017917 -0.372581 -0.176764 -0.004306
# MntMeatProducts     -0.004437   -0.030872 -0.437129 -0.261160  0.023056
# MntFishProducts     -0.024475   -0.041625 -0.387644 -0.204187  0.001079
# MntSweetProducts    -0.007642   -0.018133 -0.370673 -0.162475  0.022670
# MntGoldProds        -0.013438   -0.061818 -0.349595 -0.021725  0.016693
# NumDealsPurchases   -0.037166   -0.060846  0.221798  0.387741 -0.001098
# ...

# %%
print('Correlation:')
FP.corr()
# Out:
# Correlation:
#                            ID  Year_Birth   Kidhome  Teenhome   Recency  \
# ID                   1.000000    0.000028  0.002406 -0.002580 -0.046524
# Year_Birth           0.000028    1.000000  0.230176 -0.352111 -0.019871
# Kidhome              0.002406    0.230176  1.000000 -0.036133  0.008827
# Teenhome            -0.002580   -0.352111 -0.036133  1.000000  0.016198
# Recency             -0.046524   -0.019871  0.008827  0.016198  1.000000
# MntWines            -0.022878   -0.157773 -0.496297  0.004846  0.016064
# MntFruits            0.004600   -0.017917 -0.372581 -0.176764 -0.004306
# MntMeatProducts     -0.004437   -0.030872 -0.437129 -0.261160  0.023056
# MntFishProducts     -0.024475   -0.041625 -0.387644 -0.204187  0.001079
# MntSweetProducts    -0.007642   -0.018133 -0.370673 -0.162475  0.022670
# MntGoldProds        -0.013438   -0.061818 -0.349595 -0.021725  0.016693
# NumDealsPurchases   -0.037166   -0.060846  0.221798  0.387741 -0.001098
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
FP.colums=("ID","Year_Birth","Education","Marital_Status","Income","Kidhome","Teenhome","Dt_Customer","Recency","MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds","NumDealsPurchases","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumWebVisitsMonth","AcceptedCmp3","AcceptedCmp4","AcceptedCmp5","AcceptedCmp1","AcceptedCmp2","Response","Complain","Country")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
FP['Education'].value_counts()
# Out:
# BachelorsDegree    1127
# PhD                 486
# Master              370
# HighSchool          257
# Name: Education, dtype: int64

# %%
FP['Income'].value_counts()
# Out:
# $7,500.00      12
# $35,860.00      4
# $18,929.00      3
# $47,025.00      3
# $34,176.00      3
#                ..
# $41,120.00      1
# $34,633.00      1
# $52,854.00      1
# $61,314.00      1
# $41,411.00      1
# Name: Income, Length: 1974, dtype: int64

# %%
sns.countplot(x='Complain', data=FP)

# %%
print (FP.describe())
x = FP.drop(['Education','Marital_Status','Income'], axis=1)
y = FP['Income']
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
sns.scatterplot(x='Complain', y='Income', data=FP)

# %%
sns.countplot(FP['Education'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Country', data=FP)

# %%
FP['Teenhome'].plot.hist(title='FP w/ Teens home')

# %%
FP['Kidhome'].plot.hist(title='FP w/ Kids home')

# %%
FP['Teenhome'].value_counts()
# Out:
# 0    1158
# 1    1030
# 2      52
# Name: Teenhome, dtype: int64

# %%
FP['Kidhome'].value_counts()
# Out:
# 0    1293
# 1     899
# 2      48
# Name: Kidhome, dtype: int64

# %%
plt.hist(FP['Complain'],bins=5)
# Out:
# (array([2219.,    0.,    0.,    0.,   21.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(FP['Marital_Status'],bins=40)
# Out:
# (array([864.,   0.,   0.,   0.,   0.,   0., 480.,   0.,   0.,   0.,   0.,
#           0.,   0.,  77.,   0.,   0.,   0.,   0.,   0.,   0., 232.,   0.,
#           0.,   0.,   0.,   0., 580.,   0.,   0.,   0.,   0.,   0.,   0.,
#           3.,   0.,   0.,   0.,   0.,   0.,   4.]),
#  array([0.  , 0.15, 0.3 , 0.45, 0.6 , 0.75, 0.9 , 1.05, 1.2 , 1.35, 1.5 ,
#         1.65, 1.8 , 1.95, 2.1 , 2.25, 2.4 , 2.55, 2.7 , 2.85, 3.  , 3.15,
#         3.3 , 3.45, 3.6 , 3.75, 3.9 , 4.05, 4.2 , 4.35, 4.5 , 4.65, 4.8 ,
#         4.95, 5.1 , 5.25, 5.4 , 5.55, 5.7 , 5.85, 6.  ]),
#  <a list of 40 Patch objects>)

# %%
sns.jointplot('Year_Birth','Income' ,data=FP)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
